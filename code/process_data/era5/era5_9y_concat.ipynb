# %%
# Add cloud to sst glorys
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import sys
import matplotlib.pyplot as plt
import numpy as np
import os
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.ticker as mticker

folder_data = "/Odyssey/private/t22picar/data/era5/"
file_glorys = "era5_2010_dailymean_4th.nc"
maps_glorys = xr.open_dataset(folder_data+file_glorys)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Odyssey/private/t22picar/miniforge3/envs/4dvarnet-daniel/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /Odyssey/private/t22picar/miniforge3/envs/4dvarnet-daniel/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Odyssey/private/t22picar/data/era5/era5_2010_dailymean_4th.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '5349dfbd-e094-4e35-b7c6-fb6b5518e9f8']
#
# ...

# %%
maps_glorys
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:  (time: 365, lat: 680, lon: 1440)
# Coordinates:
#   * time     (time) datetime64[ns] 3kB 2010-01-01 2010-01-02 ... 2010-12-31
#   * lat      (lat) float64 5kB -80.0 -79.75 -79.5 -79.25 ... 89.5 89.75 90.0
#   * lon      (lon) float64 12kB -180.0 -179.7 -179.5 ... 179.4 179.7 179.9
# Data variables:
#     u10      (time, lat, lon) float64 3GB ...
#     v10      (time, lat, lon) float64 3GB ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-05-13T14:38 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
for year in range(2010,2019):
    print(year)
    file_glorys = f"era5_{year}_dailymean_4th.nc"
    maps_glorys_i = xr.open_dataset(folder_data+file_glorys)
    print("Concatenation ... ")
    maps_glorys = xr.concat([maps_glorys, maps_glorys_i], dim='time')
    print("Concatenation done ")
# Out:
# 2010
# Concatenation ...
# Concatenation done
# 2011
# Concatenation ...
# Concatenation done
# 2012
# Concatenation ...
# Concatenation done
# 2013
# Concatenation ...
# Concatenation done
# 2014
# Concatenation ...
# Concatenation done
# 2015
# Concatenation ...
# Concatenation done
# 2016
# Concatenation ...
# Concatenation done
# 2017
# Concatenation ...
# Concatenation done

# %%
maps_glorys
# Out:
# <xarray.Dataset> Size: 51GB
# Dimensions:  (time: 3287, lat: 680, lon: 1440)
# Coordinates:
#   * time     (time) datetime64[ns] 26kB 2010-01-01 2010-01-02 ... 2017-12-31
#   * lat      (lat) float64 5kB -80.0 -79.75 -79.5 -79.25 ... 89.5 89.75 90.0
#   * lon      (lon) float64 12kB -180.0 -179.7 -179.5 ... 179.4 179.7 179.9
# Data variables:
#     u10      (time, lat, lon) float64 26GB nan -0.02459 ... 0.07275 0.07275
#     v10      (time, lat, lon) float64 26GB nan -2.662 -2.627 ... -0.0826 -0.0826
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-05-13T14:38 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# save data 
save_file="era5_2010-2018_dailymean_4th.nc"
# Sauvegarder le DataArray en fichier NetCDF
maps_glorys.to_netcdf(folder_data+save_file)

# %%
# Add cloud to sst glorys
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import sys
import matplotlib.pyplot as plt
import numpy as np
import os
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.ticker as mticker

folder_data = "/Odyssey/private/t22picar/data/era5/"
file_glorys = "era5_2010-2018_dailymean_4th.nc"
maps_glorys = xr.open_dataset(folder_data+file_glorys)

year=2018
print(year)
file_glorys = f"era5_{year}_dailymean_4th.nc"
maps_glorys_i = xr.open_dataset(folder_data+file_glorys)
print("Concatenation ... ")
maps_glorys = xr.concat([maps_glorys, maps_glorys_i], dim='time')
print("Concatenation done ")
# Out:
# 2018
# Concatenation ...

# %%
# save data 
save_file="era5_2010-2018_dailymean_4th_2.nc"
# Sauvegarder le DataArray en fichier NetCDF
maps_glorys.to_netcdf(folder_data+save_file)
