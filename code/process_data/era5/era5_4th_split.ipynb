# %%
# Add cloud to sst glorys
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import sys
import matplotlib.pyplot as plt
import numpy as np
import os
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
import cfgrib

folder_data = "/Odyssey/private/t22picar/data/era5/"
#file_glorys = "era5_2019-2021_hourly.grib" # Actually not glorys 
file_glorys = "era5_2019-2021_dailymean_4th.nc"
maps_glorys = xr.open_dataset(folder_data+file_glorys)

# %%
maps
# Out:
# <xarray.Dataset> Size: 18GB
# Dimensions:  (time: 457, lat: 680, lon: 1440)
# Coordinates:
#     depth    float32 4B ...
#   * time     (time) datetime64[ns] 4kB 2020-01-20 2020-01-21 ... 2021-04-20
#   * lat      (lat) float64 5kB -80.0 -79.75 -79.5 -79.25 ... 89.5 89.75 90.0
#   * lon      (lon) float64 12kB -180.0 -179.7 -179.5 ... 179.4 179.7 179.9
# Data variables:
#     mlotst   (time, lat, lon) float64 4GB ...
#     uo       (time, lat, lon) float64 4GB ...
#     vo       (time, lat, lon) float64 4GB ...
#     zos      (time, lat, lon) float64 4GB ...
#     thetao   (time, lat, lon) float64 4GB ...
# Attributes:
#     references:                http://www.mercator-ocean.fr
#     comment:                   CMEMS product
#     title:                     daily mean fields from Global Ocean Physics An...
#     source:                    MERCATOR GLORYS12V1
#     institution:               MERCATOR OCEAN
# ...

# %%
maps_glorys = maps_glorys.drop("number").drop("step").drop("surface").rename({"valid_time": "time"})
tstart = "20-01-2020"
tend= "20-04-2021"
maps_glorys = maps_glorys.sel(time=slice(tstart,tend))

# %%
maps_glorys
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:  (time: 457, lat: 680, lon: 1440)
# Coordinates:
#   * time     (time) datetime64[ns] 4kB 2020-01-20 2020-01-21 ... 2021-04-20
#   * lat      (lat) float64 5kB -90.0 -89.73 -89.47 -89.2 ... 89.47 89.73 90.0
#   * lon      (lon) float64 12kB 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
# Data variables:
#     u10      (time, lat, lon) float64 4GB ...
#     v10      (time, lat, lon) float64 4GB ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-04-23T10:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# save data 
save_file="era5_2020-2021_dailymean_4th.nc"
# Sauvegarder le DataArray en fichier NetCDF
maps_glorys.to_netcdf(folder_data+save_file)

# %%
maps = xr.open_dataset("/Odyssey/private/t22picar/data/glorys_2020_15m/glorys_15.81m_2020-01-20-2021-04-20_4th.nc")

# %%
folder_data = "/Odyssey/private/t22picar/data/era5/"
#file_glorys = "era5_2019-2021_hourly.grib" # Actually not glorys 
file_glorys = "era5_2020_2021_dailymean_4th.nc"

maps_glorys = xr.open_dataset(folder_data+file_glorys)

# %%
maps_glorys
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:  (time: 457, lat: 680, lon: 1440)
# Coordinates:
#   * time     (time) datetime64[ns] 4kB 2020-01-20 2020-01-21 ... 2021-04-20
#   * lat      (lat) float64 5kB -80.0 -79.75 -79.5 -79.25 ... 89.5 89.75 90.0
#   * lon      (lon) float64 12kB -80.0 -79.88 -79.76 -79.65 ... 89.76 89.88 90.0
# Data variables:
#     u10      (time, lat, lon) float64 4GB ...
#     v10      (time, lat, lon) float64 4GB ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-04-23T15:44 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
np.mean(maps_glorys.u10.values)
# Out:
# -0.04429678009874722

# %%
maps_glorys.u10.mean().values.item()
# Out:
# (-0.04429678009874722,)
