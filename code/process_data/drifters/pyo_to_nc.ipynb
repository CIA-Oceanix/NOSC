# %%
import write_utils

# %%
tonpickledic =

# %%
for ide,idedic in tonpickledic.items():
    file_name = os.path.join(yourpath, f’drifter_{ide}.nc’)
    write_utils.save_netcdf(filename, idedic, ’time')
