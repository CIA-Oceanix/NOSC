# %%
import velocity_metrics.lagrangian.drifters as drifters
import velocity_metrics.lagrangian.cumulative_distance as sde
import velocity_metrics.utils.constant as const  
import os
import warnings
import sys
import datetime
warnings.filterwarnings("ignore")
import json
import logging

# Configuration du logger pour afficher les messages dans le notebook
logging.basicConfig(
    level=logging.INFO,  # Niveau minimal de log à afficher (INFO, DEBUG, WARNING, etc.)
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',  # Format des messages
    handlers=[logging.StreamHandler()])  # Affiche les logs dans la sortie standard
# Récupération du xp_name 
xp_name = "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost"
print(xp_name)
base_output="./"


if "_0m" in xp_name or "_00m" in xp_name:
    depth = 0
    depth_ind=0
    print(f"depth = {depth}")
elif "_15m" in xp_name:
    depth = 15
    depth_ind=1
    print(f"depth = {depth}")
else: 
    print("!!! no depth in xp name !!!")
    depth = 15
    depth_ind=1


# Formater depth avec deux chiffres significatifs

depth_formatted = "{:02}".format(depth)
input_dict = f'{base_output}metric/dictionary/'
input_drifter = '/Odyssey/private/t22picar/2024_DC_WOC-ESA/dc_data/drifter/'
outputdir = f'{base_output}rec/{xp_name}/metric'

### TO CHANGE FOR BOX SIZE ###

dir_output = "metric"
path_drifter_param = input_dict + 'drifters_parameters.ini'

path_dict_product = input_dict+f'{xp_name}.json' 

first_date = datetime.datetime.strptime('20190101T000000Z', const.FMT)
last_date  = datetime.datetime.strptime('20191231T000000Z', const.FMT) 


input_lagrangian_position = '/Odyssey/private/t22picar/2024_DC_WOC-ESA/dc_data/lagrangian_position_pickle/'
input_lagrangian_position = '/Odyssey/private/t22picar/data/drifters/AOML/json/'

region="California"
outputdir = f'{base_output}rec/{xp_name}/{dir_output}/{region}/'
path_dict_region = input_dict + f'region_{region}.json'
# Formater depth avec deux chiffres significatifs
#path_drifter_param = input_dict + 'drifters_parameters.ini'
path_drifter_position = input_lagrangian_position + f'Fictive_pos_Drifters_AOML_GL_{depth_formatted}m_20190101T000000Z_20200101T000000Z.pyo.json' 
first_date = '20190101T000000Z'
last_date = '20191231T000000Z'
advection_days = 10


# 1394187
# 1394187
# Out:
# unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost
# depth = 15

# %%
# Désactiver tous les logs
logging.disable(logging.CRITICAL)

_ = drifters.run_all_load_once(path_drifter_param, path_dict_product, path_drifter_position,
                 days_of_advection=advection_days, output_dir=outputdir, region=path_dict_region, 
                 first_date=first_date, last_date=last_date, sdepth=depth_ind)
# Out:
# Domaine :
# [-135, -115, 20, 50]
# None
# Percent: [##############################] 99.73%, ,
#   0%|          | 51/20719 [00:15<1:44:58,  3.28it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/lagrangian/drifters.py:303, in drifter(parameter_file, VEL, first_date, last_date, coord, parallelisation, save_netcdf, fictive_drifter, output_dir, dic_global_attr, pattern, verbose)
#     302 try:
# --> 303     list_var_adv = mod_advection.advection(reducepart, dic_vel, par_advection,
#     304                                            par_output, i0, i1, listGr,
#     305                                            grid, rank=rank, size=size,
#     306                                            verbose=verbose)
#     307 except:
#
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/lagrangian/mod_advection.py:285, in advection(part, dic, par, paro, i0, i1, listGr, grid, rank, size, verbose, AMSR)
#     284 rk = r[:, k]
# --> 285 advect = advection_pa_timestep_np(par, lonpa, latpa, dt, ind_t,
#     286                                   mask, rk, dic['u'], dic['v'])
#     287 if advect is None: continue
#
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/lagrangian/mod_advection.py:137, in advection_pa_timestep_np(par, lonpa, latpa, dt, interp_dt, mask, rk, _interp_u, _interp_v)
#     136     _interp_ut = _interp_ut - 360
# --> 137 dlondt = numpy.sign(tadvection) * _interp_ut
#     138 dlatdt = numpy.sign(tadvection) * _interp_vt
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Désactiver tous les logs
#       2 logging.disable(logging.CRITICAL)
# ----> 4 _ = drifters.run_all_load_once(path_drifter_param, path_dict_product, path_drifter_position,
#       5                  days_of_advection=advection_days, output_dir=outputdir, region=path_dict_region,
#       6                  first_date=first_date, last_date=last_date, sdepth=depth_ind)
#
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/lagrangian/drifters.py:151, in run_all_load_once(par, data_type_file, list_drifter_position, days_of_advection, region, sdepth, output_dir, pattern, first_date, last_date, save_netcdf)
#     146 kide, _ = ide.split('_')
#     147 dic_global_attr = {'ide': kide, 'pattern': pattern2,
#     148                    'data_type': data_type,
#     149                    'depth': depth[sdepth], 'label': label,
#     150                    }
# --> 151 dic_d = drifter(par, VEL_small, dfirst_date, dlast_date, coord_small,
#     152                 dic_global_attr=dic_global_attr,
#     153                 fictive_drifter=[float(part['lon']), float(part['lat'])],
#     154                 output_dir=output_dir, verbose=False,
#     155                 pattern=f'{int(kide):015d}', save_netcdf=save_netcdf)
#     156 for key, value in dic_global_attr.items():
#     157     dic_d[key] = value
#
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/lagrangian/drifters.py:308, in drifter(parameter_file, VEL, first_date, last_date, coord, parallelisation, save_netcdf, fictive_drifter, output_dir, dic_global_attr, pattern, verbose)
#     303     list_var_adv = mod_advection.advection(reducepart, dic_vel, par_advection,
#     304                                            par_output, i0, i1, listGr,
#     305                                            grid, rank=rank, size=size,
#     306                                            verbose=verbose)
#     307 except:
# --> 308     logger.error(f'Error in advection for drifter {ide}')
#     309     return None
#     310 dim_hr[0] = numpy.shape(list_var_adv['lon_hr'])[0]
#
# NameError: name 'ide' is not defined

# %%
input_drifter = "/Odyssey/private/t22picar/data/drifters/AOML/"

drifter_list = [input_drifter + f'Drifters_AOML_GL_{depth_formatted}m_20190101T000000Z_20200101T000000Z.pyo.gz']
#region="Agulhas"
#drifter_list = path_drifter_position
path_artificial_drifters = os.path.join(outputdir,f'{xp_name}_region_{region}_dep{depth_ind}.pyo.gz')
print(path_artificial_drifters)
outputfilename = f'SDE_region_{region}_20190101-20191231'
outputdir_plot=outputdir+'/plot/'

_ = sde.run(path_artificial_drifters, drifter_list, output_dir=outputdir_plot, output_filename=outputfilename,isplot=False)
# Out:
# ./rec/unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost/metric/California/unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_region_California_dep1.pyo.gz
#   1%|          | 189/20096 [00:30<53:46,  6.17it/s]
# Abort is in progress...hit ctrl-c again within 5 seconds to forcibly terminate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 9
#       6 outputfilename = f'SDE_region_{region}_20190101-20191231'
#       7 outputdir_plot=outputdir+'/plot/'
# ----> 9 _ = sde.run(path_artificial_drifters, drifter_list, output_dir=outputdir_plot, output_filename=outputfilename,isplot=False)
#
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/lagrangian/cumulative_distance.py:44, in run(input_path, drifter_file, output_dir, output_filename, isplot)
#      41 def run(input_path: str, drifter_file: str, output_dir: Optional[str] = './',
#      42         output_filename: Optional[str] = None, isplot: Optional[bool] = False,
#      43         ) -> dict:
# ---> 44     dic = process_all_ide(input_path, drifter_file, output_dir,
#      45                           output_filename, isplot=isplot)
#      46     return dic
#
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/lagrangian/cumulative_distance.py:498, in process_all_ide(input_path, drifter_pyo, dir_out, file_out, isplot, projection)
#     495 if hrtime[-1] > ddays[-1]:
#     496     continue
# --> 498 sde, dde, _lon_interp, _lat_interp = compute_nlcs(_lon, _lat, ddays,
#     499                                                   hrlon, hrlat, hrtime)
#     500 if numpy.all(sde[:-1] != sde[:-1]):
#     501     continue
#
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/lagrangian/cumulative_distance.py:349, in compute_nlcs(lon_d, lat_d, time_d, lon_f, lat_f, time_f)
#     347 for i in range(first_time, it+1):
#     348     dde_sum +=  dde[i-1, pa]
# --> 349     lld_sum += sum(lld[first_time:i])
#     350 #lld_sum += lld[it + i + 1]
#     351 sde[it, pa] = dde_sum / lld_sum if lld_sum != 0 else numpy.nan
#
# KeyboardInterrupt:

# %%
outputdir
# Out:
# './rec/unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost/metric/California/'
