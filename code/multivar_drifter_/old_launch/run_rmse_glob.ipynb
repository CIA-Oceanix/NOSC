# %%
import velocity_metrics.utils.constant as const 
import velocity_metrics.eulerian.eulerian_drifters as eulerian  
import datetime
import sys   
from IPython.display import display, Markdown
import matplotlib.pyplot as plt
import cartopy 
import warnings 
warnings.filterwarnings("ignore") 
sys.path.append('/Odyssey/private/t22picar/2024_DC_WOC-ESA/')
#from src import utils

# %%
xp_name = "neurost_sst_ssh_15m_4th"
print(xp_name)

### Creation du fichier .json

base_output="./"
path_files=f'{base_output}rec/{xp_name}/daily/'

# Chemin vers le fichier JSON
file_path = f'{base_output}metric/dictionary/'
file_name = 'data_type_metric_generic.json'

# Calcul des metrics 

if "_0m" in xp_name:
    depth = 0
elif "_15m" in xp_name:
    depth = 15
else: 
    print("no depth in xp name")
    depth = 15
# Formater depth avec deux chiffres significatifs
depth_formatted = "{:02}".format(depth)


input_dict = f'{base_output}metric/dictionary/'
input_drifter = '/Odyssey/private/t22picar/data/drifters/AOML/'
outputdir = f'{base_output}rec/{xp_name}/metric'

path_dict_product = input_dict+f'{xp_name}.json' 

first_date = datetime.datetime.strptime('20190101T000000Z', const.FMT)
last_date  = datetime.datetime.strptime('20191231T000000Z', const.FMT) 

outputdir = f'{base_output}rec/{xp_name}/metric/California/'

path_dict_region = input_dict+'region_California.json'

# Warning ! CMEMS instead of AOML ?!
drifter_list = [input_drifter+f'Drifters_AOML_GL_15m_20190101T000000Z_20200101T000000Z.pyo.gz']

eulerian.run(drifter_list, path_dict_product, 
             first_date=first_date, last_date=last_date, 
             region=path_dict_region, sdepth=1, output_dir=outputdir)
# Out:
# neurost_sst_ssh_15m_4th
# None
# Percent: [##############################] 99.73%, ,
# Compute and save statistics in ./rec/neurost_sst_ssh_15m_4th/metric/California/ directory

# %%
xp_name = "unet_uv_drifters_aoml_15m_10y_11d_ugos_lat"
print(xp_name)

### Creation du fichier .json

base_output="./"
path_files=f'{base_output}rec/{xp_name}/daily/'

# Chemin vers le fichier JSON
file_path = f'{base_output}metric/dictionary/'
file_name = 'data_type_metric_generic.json'

# Calcul des metrics 

if "_0m" in xp_name:
    depth = 0
elif "_15m" in xp_name:
    depth = 15
else: 
    print("no depth in xp name")
    depth = 15
# Formater depth avec deux chiffres significatifs
depth_formatted = "{:02}".format(depth)


input_dict = f'{base_output}metric/dictionary/'
input_drifter = '/Odyssey/private/t22picar/data/drifters/AOML/'
outputdir = f'{base_output}rec/{xp_name}/metric'

path_dict_product = input_dict+f'{xp_name}.json' 

first_date = datetime.datetime.strptime('20190101T000000Z', const.FMT)
last_date  = datetime.datetime.strptime('20191231T000000Z', const.FMT) 

outputdir = f'{base_output}rec/{xp_name}/metric/Global/'

path_dict_region = input_dict+'region_global.json'

# Warning ! CMEMS instead of AOML ?!
drifter_list = [input_drifter+f'Drifters_AOML_GL_15m_20190101T000000Z_20200101T000000Z.pyo.gz']

eulerian.run(drifter_list, path_dict_product, 
             first_date=first_date, last_date=last_date, 
             region=path_dict_region, sdepth=1, output_dir=outputdir)
# Out:
# unet_uv_drifters_aoml_15m_10y_11d_ugos_lat
# None
# Percent: [##############################] 99.73%, ,
# Compute and save statistics in ./rec/unet_uv_drifters_aoml_15m_10y_11d_ugos_lat/metric/Global/ directory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 42
#      39 # Warning ! CMEMS instead of AOML ?!
#      40 drifter_list = [input_drifter+f'Drifters_AOML_GL_15m_20190101T000000Z_20200101T000000Z.pyo.gz']
# ---> 42 eulerian.run(drifter_list, path_dict_product,
#      43              first_date=first_date, last_date=last_date,
#      44              region=path_dict_region, sdepth=1, output_dir=outputdir)
#
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/eulerian/eulerian_drifters.py:71, in run(drifter_paths, data_type_file, first_date, last_date, region, sdepth, output_dir, temporal_filtering, size_box)
#      69 dic_drif = read_drifters.load_drifter_pickle(list(drifter_paths))
#      70 logger.warn(f'Compute and save statistics in {output_dir} directory')
# ---> 71 mean_dic, std_dic, res_map = run_compute_error(VEL, coord, dic_drif,
#      72                                       averaging=spatial_cov_h*3600,
#      73                                       temporal_filtering=temporal_filtering,
#      74                                       box=box, size_box=size_box)
#      75 os.makedirs(output_dir, exist_ok=True)
#      76 _file = os.path.join(output_dir, f'Eulerian_RMS_{data_type}.pyo')
#
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/eulerian/eulerian_drifters.py:262, in run_compute_error(VEL, coord, dic_drif, averaging, temporal_filtering, box, size_box)
#     256 def run_compute_error(VEL: dict, coord: dict, dic_drif: dict,
#     257                       averaging: Optional[float] = 3600,
#     258                       temporal_filtering: Optional[float] = 0,
#     259                       box: Optional[list] = None, size_box: Optional[int] = 2
#     260                       ) -> Tuple[dict, dict]:
#     261     # Compute difference velocity-drifters
# --> 262     out_dic = compute_error(VEL, coord, dic_drif, averaging,
#     263                             temporal_filtering)
#     264     mean_dic = {}
#     265     std_dic = {}
#
# File /Odyssey/private/t22picar/miniforge3/envs/bench_env/lib/python3.13/site-packages/velocity_metrics/eulerian/eulerian_drifters.py:407, in compute_error(dic, coord, dic_drif, _av, filt)
#     405 _av0 = _time - numpy.timedelta64(int(_av / 2), 's')
#     406 _av1 = _time + numpy.timedelta64(int(_av / 2), 's')
# --> 407 _it = numpy.where((dt >= (_av0)) & (dt <= (_av1)))[0]
#     408 if not _it.any():
#     409     continue
#
# KeyboardInterrupt:
