# %%
import velocity_metrics.utils.constant as const 
import velocity_metrics.eulerian.eulerian_drifters as eulerian  
import datetime
import sys   
from IPython.display import display, Markdown
import matplotlib.pyplot as plt
import cartopy 
import warnings 
warnings.filterwarnings("ignore") 
sys.path.append('/Odyssey/private/t22picar/2024_DC_WOC-ESA/')
from src import utils
from multivar_drifter.metric.eulerian.plot_rmse import plot_rmse_score_0m, plot_rmse_score_15m
from multivar_drifter.metric.eulerian.plot_GL_metric import plot_rmse_score

listkey_comp = ('Eastward Correlation','Northward Correlation','Norm Correlation', 
           'Eastward Explained Variance (%)', 'Northward Explained Variance (%)','Norm Explained Variance (%)',
           'Number of Points')

listkey_comp = ('Eastward RMSD', 'Northward RMSD','Norm RMSD', 
           'Eastward Correlation', 'Northward Correlation','Norm Correlation', 
           'Eastward Explained Variance (%)', 'Northward Explained Variance (%)','Norm Explained Variance (%)',
           'Number of Points')

listkey_comp = ('Eastward RMSD', 'Northward RMSD','Norm RMSD', 'Eastward Correlation', 'Northward Correlation','Norm Correlation','Eastward MSD Explained Variance (%)', 'Northward MSD Explained Variance (%)','Norm MSD Explained Variance (%)',
           'Number of Points')

list_region=["Agulhas","GulfStream","Mediterranean","California","NA"]

# %%
list_region=["Agulhas","GulfStream","Mediterranean","California","NA"]

list_xp_name=[#"neurost_sst_ssh_15m_10th",
                #"unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost" ,
                #"unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet",
                "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs",
                "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet",


]


plot_rmse_score(list_xp_name,list_region,depth=15,keys=listkey_comp)
# Out:
# Agulhas result
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# ...

# %%
list_xp_name=["neurost_sst_ssh_15m_10th",
                "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost" ,
                "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_u10n",
]

plot_rmse_score(list_xp_name,list_region,depth=15,keys=listkey_comp)
# Out:
# Agulhas result
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# ...

# %%
list_xp_name=["neurost_sst_ssh_15m_10th",
                "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost" ,
                "unet_uv_aoml_15m_10y_11d_bathy_mae_neurost_MW" ,
                "unet_uv_aoml_15m_10y_11d_bathy_mae_neurost_SST", 
                "unet_uv_aoml_15m_10y_11d_bathy_mae_neurost"
]

plot_rmse_score(list_xp_name,list_region,depth=15,keys=listkey_comp)
# Out:
# Agulhas result
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# ...

# %%
list_region=["Agulhas","GulfStream","Mediterranean","California","NA"]

list_xp_name=["neurost_sst_ssh_15m_10th",
                #"GC_15m_4th_h",
                #"globcurrent_15m_4th",
                "duacs_15m_8th",
                "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_imt" ,
                "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs",
                "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost" ,
                #"unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2010_neurost_fine",
                #"unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_drop",

                "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_res",
                #"unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_8th_neurost_finetune",
                "unet_uv_aoml_15m_10y_11d_bathy_mae_neurost_MW",
                "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_u10n",
                "unet_uv_aoml_15m_10y_11d_bathy_mae_neurost_SST",


]
plot_rmse_score(list_xp_name,list_region,depth=15,keys=listkey_comp)
# Out:
# Agulhas result
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# ...

# %%
list_region=["Agulhas","GulfStream"]

list_xp_name=[ "globcurrent_15m_4th",
                "GC_15m_4th_h" ]

plot_rmse_score_15m(list_xp_name,keys=listkey_comp,add_neurost=False)
# Out:
# depth = 15m
# Agulhas result
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# ...

# %%
xp_name=["neurost_sst_ssh_15m_10th",
        "GC_15m_4th_h",
        "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs",
        "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_imt",
        "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2010_neurost_fine",
        #"unet_uv_drifters_aoml_15m_10y_11d_bathy_mae",
        #"unet_uv_drifters_aoml_15m_10y_11d_bathy_sst_mae",
        #"unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae",
]


if "0m" in xp_name[0]:
    plot_rmse_score_0m(xp_name)
elif "15m" in xp_name[0]:
    plot_rmse_score_15m(xp_name,keys=listkey_comp,add_neurost=False)
else:
    plot_rmse_score_15m(xp_name)
# Out:
# depth = 15m
# Agulhas result
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# ...

# %%
xp_name=["neurost_sst_ssh_15m_10th",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost",
        #"unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2010",
        #"unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2010_neurost",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2010_neurost_no_norm"

]


if "0m" in xp_name[0]:
    plot_rmse_score_0m(xp_name)
elif "15m" in xp_name[0]:
    plot_rmse_score_15m(xp_name,keys=listkey_comp,add_neurost=False)
else:
    plot_rmse_score_15m(xp_name)
# Out:
# depth = 15m
# Agulhas result
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Explained Variance (%)</b></td>
# ...

# %%
xp_name=[
        "unet_uv_drifters_aoml_15m_10y_11d_ugos_lat",
        "unet_uv_drifters_cmems_15m_10y_11d_ugos_lat",
]

xp_name=["neurost_sst_ssh_15m_10th",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae",
        "unet_uv_drifters_aoml_15m_10y_9d_bathy_no_sst_mae",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_SB",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost",
]


xp_name=["neurost_sst_ssh_15m_10th",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_SB",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_mae_val",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_mld_mae",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_chl_mae",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_sst_log",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_test_domain",
        "unet_uv_drifters_cmems_15m_10y_11d_bathy_no_sst_mae_test_domain",
        "unet_uv_drifters_aoml_15m_10y_9d_bathy_no_sst_wind_mae_8th_2010",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2014",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_imt"

]


xp_name=[#"neurost_sst_ssh_15m_10th",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_test_domain",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_mld_mae",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_sst_log",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_96",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_SB",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2014"

]

xp_name=["neurost_sst_ssh_15m_10th",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_mae_sst_MW",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_mae_val",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_lr_1e-2",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2014",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_96",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_nofill",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_500tb"
        

]



xp_name=["neurost_sst_ssh_15m_10th",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_nofill"
]

# %%
from multivar_drifter.metric.eulerian.plot_rmse import DictTable_color

base_outputdir = "../"
list_xp_name=["neurost_sst_ssh_15m_10th",
                "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae",
              "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost",
              "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2010",
              "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2010_neurost",
              "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_8th_2010_neurost_no_norm"]
list_dict=[]
for xp_name in list_xp_name:
    outputdir = f'{base_outputdir}rec/{xp_name}/metric/California/'
    list_dict = list_dict+[{'type_stat':'Mean','path':outputdir+f'/Eulerian_RMS_{xp_name}.pyo','name':f'{xp_name}'}] 

display(DictTable_color(list_dict,keys=listkey_comp))
# Out:
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Explained Variance (%)</b></td>
# ...

# %%
listkey_comp = ('Eastward Correlation', 'Northward Correlation','Norm Correlation','Eastward MSD Explained Variance (%)', 'Northward MSD Explained Variance (%)','Norm MSD Explained Variance (%)',
           'Number of Points')

xp_name=["neurost_sst_ssh_15m_10th",
        "globcurrent_15m_4th",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_SB",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae"
        #"unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_lr",
        #"unet_uv_drifters_aoml_15m_10y_9d_bathy_no_sst_mae",
]

xp_name=[
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_weight_decay",
        "unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_lr_1e-2",

]

plot_rmse_score_15m(xp_name,keys=listkey_comp,add_neurost=False)
# Out:
# depth = 15m
# Agulhas result
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Number of Points</b></td>
# </tr>
# <tr>
# ...

# %%
list_xp_name=["ssh_duacs_sst_w_to_u_v_11d_15m","drifters_ssh_duacs_sst_w_to_u_v_11d_15m"]
dir_eulerian = '/Odyssey/private/t22picar/2024_DC_WOC-ESA/dc_product_evaluation/DC_product_evaluation/eulerian_rms/'

print("depth = 15m")


list_dict = [ {'type_stat':'Mean','path':dir_eulerian+'eulerian_rms_T1_cmems_015_004_15/Eulerian_RMS_015_004.pyo','name':'GlobCurrent Total'},
            {'type_stat':'Mean','path':dir_eulerian+'eulerian_rms_T1_neurost_15/Eulerian_RMS_neurost.pyo','name':'NeurOST'}]


for xp_name in list_xp_name:
    outputdir = f'/Odyssey/private/t22picar/multivar_uv/rec/{xp_name}/metric/Agulhas/'
    list_dict = list_dict+[{'type_stat':'Mean','path':outputdir+f'/Eulerian_RMS_{xp_name}.pyo','name':f'{xp_name}'}]
# Out:
# depth = 15m

# %%
import pickle


class DictTable_color():
    """
    Overridden dict class which takes a list of dictionaries and renders an HTML Table in IPython Notebook.
    The table cells are colored using a blue-to-red gradient based on their values, normalized per column.
    """

    def __init__(self, list, keys=['Norm RMSD', 'Norm Correlation', 'Norm Quadratic Error (%)', 'Norm Explained Variance (%)', 'Number of Points']):
        self.html_table = None
        self.list = list
        self.keys = keys

    def _get_min_max_per_column(self):
        """Collect min and max values for each key (column)."""
        min_max = {key: {'min': float('inf'), 'max': float('-inf')} for key in self.keys}
        for dict in self.list:
            filehandler = open(dict['path'], 'rb')
            object = pickle.load(filehandler)
            for key in self.keys:
                if key in object:
                    value = object[key]
                    if value < min_max[key]['min']:
                        min_max[key]['min'] = value
                    if value > min_max[key]['max']:
                        min_max[key]['max'] = value
        return min_max

    def _value_to_color(self, value, min_val, max_val):
        """Convert a value to a RGB color between blue (low) and red (high)."""
        if min_val == max_val:
            return "background-color: #ffffff;"  # White if all values are the same

        # Normalize value between 0 and 1
        normalized = (value - min_val) / (max_val - min_val)

        # Use a quadratic easing for even lighter tones
        lightness = normalized ** 0.3  # Emphasize lightness

        # Very light blue (200, 230, 255) to light pink (255, 200, 220)
        red = int(200 + 55 * lightness)
        green = int(230 - 30 * lightness)
        blue = int(255 - 55 * lightness)

        return f"background-color: rgb({red}, {green}, {blue}); color: black;"


    def _value_to_color_r(self, value, min_val, max_val):
        """Convert a value to a RGB color between blue (low) and red (high)."""
        if min_val == max_val:
            return "background-color: #ffffff;"  # White if all values are the same

        # Normalize value between 0 and 1
        normalized = (value - min_val) / (max_val - min_val)

        # Use a quadratic easing for even lighter tones
        lightness = normalized ** 0.3  # Emphasize lightness

        # Very light blue (200, 230, 255) to light pink (255, 200, 220)
        red = int(200 + 55 * lightness)
        green = int(230 - 30 * lightness)
        blue = int(255 - 55 * lightness)

        return f"background-color: rgb({blue}, {green}, {red}); color: black;"
    
    def _repr_html_(self):
        min_max_per_column = self._get_min_max_per_column()

        filehandler = open(self.list[0]['path'], 'rb')
        object = pickle.load(filehandler)

        html = ["<table style='border-collapse: collapse; width: 100%; border: 1px solid black;'>"]
        html.append("<tr style='background-color: #e9ecef; color: black;'>")
        html.append("<td style='border: 1px solid black; padding: 5px;'><b>{0}</b></td>".format(self.list[0]['type_stat']))
        for key in self.keys:
            if key in object:
                html.append("<td style='border: 1px solid black; padding: 5px;'><b>{0}</b></td>".format(key))
        html.append("</tr>")

        for dict in self.list:
            filehandler = open(dict['path'], 'rb')
            object = pickle.load(filehandler)
            html.append("<tr>")
            html.append("<td style='border: 1px solid black; padding: 5px;'><b>{0}</b></td>".format(dict['name']))
            for key in self.keys:
                if key in object:
                    value = object[key]
                    min_val = min_max_per_column[key]['min']
                    max_val = min_max_per_column[key]['max']

                    if "Correlation" or "Variance" in key:
                        style = self._value_to_color_r(value, min_val, max_val)
                    else:
                        style = self._value_to_color(value, min_val, max_val)
                    html.append("<td style='border: 1px solid black; padding: 5px; {1}'>{0}</td>".format("{:.3f}".format(value), style))
            html.append("</tr>")

        html.append("</table>")
        self.html_table = '\n'.join(html)
        return self.html_table
    
def print_json(path_json):
    import json
    f = open(path_json)
    data = json.load(f)
    for i in data:
        print(i, ':', data[i])

# %%
import velocity_metrics.utils.constant as const 
import velocity_metrics.eulerian.eulerian_drifters as eulerian  
import datetime
import sys   
from IPython.display import display, Markdown
import matplotlib.pyplot as plt
import cartopy 
import warnings 
warnings.filterwarnings("ignore") 
sys.path.append('/Odyssey/private/t22picar/2024_DC_WOC-ESA/')
from src import utils
import multivar_drifter.metric.eulerian.utils_nb as utils_nb

dir_eulerian = '/Odyssey/private/t22picar/2024_DC_WOC-ESA/dc_product_evaluation/DC_product_evaluation/eulerian_rms/'
base_outputdir = "../"

print("depth = 0m")

xp_name="unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae"

outputdir = f'{base_outputdir}rec/{xp_name}/metric/GulfStream/'

list_dict = [{'type_stat':'Mean','path':dir_eulerian+'eulerian_rms_GulfStream_cmems_015_004_15/Eulerian_RMS_015_004.pyo','name':'GlobCurrent Total'}, 
                {'type_stat':'Mean','path':dir_eulerian+'eulerian_rms_GulfStream_neurost_15/Eulerian_RMS_neurost.pyo','name':'NeurOST'}]

list_dict = list_dict+[{'type_stat':'Mean','path':outputdir+f'/Eulerian_RMS_{xp_name}.pyo','name':f'{xp_name}'}] 

print("Gulfstream result")
display(DictTable_color(list_dict))
# Out:
# depth = 0m
# Gulfstream result
# Norm RMSD
# Norm Correlation
# OK
# Norm Quadratic Error (%)
# Norm Explained Variance (%)
# OK
# Number of Points
# Norm RMSD
# Norm Correlation
# OK
# Norm Quadratic Error (%)
# Norm Explained Variance (%)
# OK
# Number of Points
# Norm RMSD
# Norm Correlation
# OK
# Norm Quadratic Error (%)
# Norm Explained Variance (%)
# OK
# Number of Points
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Quadratic Error (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Explained Variance (%)</b></td>
# ...

# %%
import pickle

class DictTable_color():
    """
    Overridden dict class which takes a list of dictionaries and renders an HTML Table in IPython Notebook.
    The table cells are colored using a very light blue-to-pink gradient.
    The smallest value in each column is displayed in bold.
    """

    def __init__(self, list, keys=['Norm RMSD', 'Norm Correlation', 'Norm Quadratic Error (%)', 'Norm Explained Variance (%)', 'Number of Points']):
        self.html_table = None
        self.list = list
        self.keys = keys

    def _get_min_max_per_column(self):
        """Collect min and max values for each key (column)."""
        min_max = {key: {'min': float('inf'), 'max': float('-inf')} for key in self.keys}
        min_indices = {key: None for key in self.keys}
        max_indices = {key: None for key in self.keys}
        for i, dict in enumerate(self.list):
            filehandler = open(dict['path'], 'rb')
            object = pickle.load(filehandler)
            for key in self.keys:
                if key in object:
                    value = object[key]
                    if value < min_max[key]['min']:
                        min_max[key]['min'] = value
                        min_indices[key] = i
                    if value > min_max[key]['max']:
                        min_max[key]['max'] = value
                        max_indices[key] = i
        return min_max, min_indices, max_indices

    def _value_to_color(self, value, min_val, max_val):
        """Convert a value to a very light RGB color, from pastel blue to light pink."""
        if min_val == max_val:
            return "background-color: #ffffff; color: black;"

        # Normalize value between 0 and 1
        normalized = (value - min_val) / (max_val - min_val)

        # Use a quadratic easing for even lighter tones
        lightness = normalized ** 0.3

        # Very light blue (200, 230, 255) to light pink (255, 200, 220)
        red = int(200 + 55 * lightness)
        green = int(230 - 30 * lightness)
        blue = int(255 - 55 * lightness)

        return f"background-color: rgb({red}, {green}, {blue}); color: black;"


    def _value_to_color_r(self, value, min_val, max_val):
        """Convert a value to a RGB color between blue (low) and red (high)."""
        if min_val == max_val:
            return "background-color: #ffffff;"  # White if all values are the same

        # Normalize value between 0 and 1
        normalized = (value - min_val) / (max_val - min_val)

        # Use a quadratic easing for even lighter tones
        lightness = normalized ** 0.3  # Emphasize lightness

        # Very light blue (200, 230, 255) to light pink (255, 200, 220)
        red = int(200 + 55 * lightness)
        green = int(230 - 30 * lightness)
        blue = int(255 - 55 * lightness)

        return f"background-color: rgb({blue}, {green}, {red}); color: black;"
    
    def _repr_html_(self):
        min_max, min_indices, max_indices = self._get_min_max_per_column()

        filehandler = open(self.list[0]['path'], 'rb')
        object = pickle.load(filehandler)

        #html = ["<table style='border-collapse: collapse; width: 100%; border: 1px solid #dddddd;'>"]
        html = ["<table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>"]
        html.append("<tr style='background-color: #f8f9fa; color: black;'>")
        html.append("<td style='border: 1px solid #000000; padding: 8px;'><b>{0}</b></td>".format(self.list[0]['type_stat']))
        for key in self.keys:
            if key in object:
                html.append("<td style='border: 1px solid #000000; padding: 8px;'><b>{0}</b></td>".format(key))
        html.append("</tr>")

        for i, dict in enumerate(self.list):
            filehandler = open(dict['path'], 'rb')
            object = pickle.load(filehandler)
            html.append("<tr>")
            html.append("<td style='border: 1px solid #000000; padding: 8px;'><b>{0}</b></td>".format(dict['name']))
            for key in self.keys:
                if key in object:
                    value = object[key]
                    min_val = min_max[key]['min']
                    max_val = min_max[key]['max']
                    print(key)
                    if "Correlation" in key or "Variance" in key:
                        print("OK")
                        style = self._value_to_color_r(value, min_val, max_val)

                        if max_indices[key] == i:
                            html.append("<td style='border: 1px solid #000000; padding: 8px; {1}'><b>{0}</b></td>".format("{:.3f}".format(value), style))
                        else:
                            html.append("<td style='border: 1px solid #000000; padding: 8px; {1}'>{0}</td>".format("{:.3f}".format(value), style))
                    else:
                        style = self._value_to_color(value, min_val, max_val)
                        # Check if this is the smallest value in the column
                        if min_indices[key] == i:
                            html.append("<td style='border: 1px solid #000000; padding: 8px; {1}'><b>{0}</b></td>".format("{:.3f}".format(value), style))
                        else:
                            html.append("<td style='border: 1px solid #000000; padding: 8px; {1}'>{0}</td>".format("{:.3f}".format(value), style))
            html.append("</tr>")

        html.append("</table>")
        self.html_table = '\n'.join(html)
        return self.html_table

def print_json(path_json):
    import json
    f = open(path_json)
    data = json.load(f)
    for i in data:
        print(i, ':', data[i])
