# %%
import pickle
import numpy as np

# %%
for region in ["GulfStream","Agulhas","Hawai"]:
    path_file = f"/Odyssey/private/t22picar/multivar_drifter/rec/unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet/metric_15m/{region}/Eulerian_RMS_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet.pyo"
    print(region)
    filehandler = open(path_file, 'rb')
    object = pickle.load(filehandler)
    print(object["Norm drifter STD"]**2)
# Out:
# GulfStream
# 0.056288032870409
# Agulhas
# 0.1715805950594749
# Hawai
# 0.015278826648292278

# %%
#Global
path_file = "/Odyssey/private/t22picar/multivar_drifter/rec/unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet/metric/Global/Eulerian_RMS_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet.pyo"
filehandler = open(path_file, 'rb')
object = pickle.load(filehandler)
object["Norm drifter STD"]
1 - (object["Norm RMSD"]**2/(object["Norm drifter STD"]**2))
# Out:
# np.float64(0.4219157297777911)

# %%
# Out:
# np.float64(0.036934582488884385)

# %%
#Global NOSCneurost
path_file = "/Odyssey/private/t22picar/multivar_drifter/rec/unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet/metric/Global/Eulerian_RMS_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet.pyo"
filehandler = open(path_file, 'rb')
object = pickle.load(filehandler)
object["Norm drifter STD"]
1 - (object["Norm RMSD"]**2/(object["Norm drifter STD"]**2))
# Out:
# np.float64(0.44241387654337083)

# %%
#Global neurost
path_file = "/Odyssey/private/t22picar/multivar_drifter/rec/neurost_sst_ssh_15m_10th/metric/Global/Eulerian_RMS_neurost_sst_ssh_15m_10th.pyo"
filehandler = open(path_file, 'rb')
object = pickle.load(filehandler)
object["Norm drifter STD"]
1 - (object["Norm RMSD"]**2/(object["Norm drifter STD"]**2))
# Out:
# np.float64(0.3591918552471358)

# %%
object["Norm drifter STD"]
# Out:
# np.float64(0.19218141230566177)

# %%
path_file = "/Odyssey/private/t22picar/multivar_drifter/rec/unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet/metric_15m/Hawai/Eulerian_RMS_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet.pyo"
filehandler = open(path_file, 'rb')
object = pickle.load(filehandler)
#object["Norm drifter STD"]
1 - (object["Norm RMSD"]**2/(object["Norm drifter STD"]**2))
# Out:
# np.float64(0.01830011483631777)

# %%
object["Norm drifter STD"]**2
# Out:
# np.float64(0.015278826648292278)

# %%
path_file = "/Odyssey/private/t22picar/multivar_drifter/rec/unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet/metric_15m/GulfStream/Eulerian_RMS_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet.pyo"
filehandler = open(path_file, 'rb')
object = pickle.load(filehandler)
object["Norm drifter STD"]
1 - (object["Norm RMSD"]/np.sqrt(object["Norm drifter STD"]))
# Out:
# np.float64(0.6198772677927411)

# %%
path_file = "/Odyssey/private/t22picar/multivar_drifter/rec/unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs/metric/Global/Eulerian_RMS_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs.pyo"
filehandler = open(path_file, 'rb')
object = pickle.load(filehandler)
object["Norm MSD Explained Variance (%)"]

# %%
filehandler = open(path_file, 'rb')
object = pickle.load(path_file)
for key in self.keys:
    if key in object:
