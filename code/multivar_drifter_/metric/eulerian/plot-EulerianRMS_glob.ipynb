# %%
import velocity_metrics.utils.constant as const 
import velocity_metrics.eulerian.eulerian_drifters as eulerian  
import datetime
import sys   
from IPython.display import display, Markdown
import matplotlib.pyplot as plt
import cartopy
import warnings 
warnings.filterwarnings("ignore") 
sys.path.append('/Odyssey/private/t22picar/2024_DC_WOC-ESA/')
from src import utils
from plot_rmse import plot_rmse_score_0m, plot_rmse_score_15m
import velocity_metrics.eulerian.eulerian_drifters as eulerian_drifters
import os
from plot_rmse import DictTable_color

# %%
listkey_comp = ( 
           'Eastward Correlation', 'Northward Correlation','Norm Correlation', 
           'Eastward Explained Variance (%)', 'Northward Explained Variance (%)','Norm Explained Variance (%)',
           'Number of Points')

listkey_comp = ('Eastward RMSD', 'Northward RMSD','Norm RMSD', 
           'Eastward Correlation', 'Northward Correlation','Norm Correlation', 
           'Eastward Explained Variance (%)', 'Northward Explained Variance (%)','Norm Explained Variance (%)',
           'Number of Points')


listkey_comp = ( 'Eastward RMSD', 'Northward RMSD','Norm RMSD', 
           'Eastward Correlation', 'Northward Correlation','Norm Correlation', 
           'Eastward MSD Explained Variance (%)', 'Northward MSD Explained Variance (%)','Norm MSD Explained Variance (%)',
           'Number of Points')

# %%
base_outputdir = "../../"
list_xp_name=[
              "neurost_sst_ssh_15m_10th",
            "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet",

]
list_dict=[]
for xp_name in list_xp_name:
    outputdir = f'{base_outputdir}rec/{xp_name}/metric/Global'
    list_dict = list_dict+[{'type_stat':'Mean','path':outputdir+f'/Eulerian_RMS_{xp_name}.pyo','name':f'{xp_name}'}] 

display(DictTable_color(list_dict,keys=listkey_comp))
# Out:
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# ...

# %%
base_outputdir = "../../"
list_xp_name=["duacs_15m_8th",
              "globcurrent_15m_4th",
              "neurost_sst_ssh_15m_10th",
            #"unet_uv_aoml_15m_10y_11d_bathy_no_sst_no_wind_mae_duacs_RonanUnet"
            "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet",
            "unet_uv_aoml_15m_10y_11d_bathy_sst_mae_duacs_RonanUnet",
            "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet",
            "unet_uv_aoml_15m_10y_11d_bathy_sst_mae_neurost_RonanUnet",
            #"unet_uv_aoml_15m_10y_11d_bathy_sst_mae_neurost_RonanUnet"

]
list_dict=[]
for xp_name in list_xp_name:
    outputdir = f'{base_outputdir}rec/{xp_name}/metric/Global'
    list_dict = list_dict+[{'type_stat':'Mean','path':outputdir+f'/Eulerian_RMS_{xp_name}.pyo','name':f'{xp_name}'}] 

display(DictTable_color(list_dict,keys=listkey_comp))
# Out:
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# ...

# %%
listkey_comp = ( 
           'Eastward MSD Explained Variance (%)', 'Northward MSD Explained Variance (%)','Norm MSD Explained Variance (%)',
           'Number of Points')

base_outputdir = "../../"
list_xp_name=[
            "unet_uv_aoml_15m_10y_11d_bathy_no_sst_no_wind_mae_duacs_RonanUnet",
            "unet_uv_aoml_15m_10y_11d_bathy_no_sst_ugos_mae_duacs_RonanUnet",
            "unet_uv_aoml_15m_10y_11d_bathy_no_sst_lat_mae_duacs_RonanUnet",
            "unet_uv_aoml_15m_10y_11d_bathy_no_sst_bathy_mae_duacs_RonanUnet",
            "unet_uv_aoml_15m_10y_11d_bathy_no_sst_ssh_mae_duacs_RonanUnet",
            "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet",
            "unet_uv_aoml_15m_10y_11d_bathy_sst_mae_duacs_RonanUnet",

]
list_dict=[]
for xp_name in list_xp_name:
    outputdir = f'{base_outputdir}rec/{xp_name}/metric/Global'
    list_dict = list_dict+[{'type_stat':'Mean','path':outputdir+f'/Eulerian_RMS_{xp_name}.pyo','name':f'{xp_name}'}] 

display(DictTable_color(list_dict,keys=listkey_comp))
# Out:
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Number of Points</b></td>
# </tr>
# <tr>
# <td style='border: 1px solid #000000; padding: 8px;'><b>unet_uv_aoml_15m_10y_11d_bathy_no_sst_no_wind_mae_duacs_RonanUnet</b></td>
# <td style='border: 1px solid #000000; padding: 8px; background-color: rgb(255, 230, 200); color: black;'>60.51</td>
# <td style='border: 1px solid #000000; padding: 8px; background-color: rgb(222, 212, 232); color: black;'>51.12</td>
# ...

# %%
data = [
    {
        "Mean": "unet_uv_aoml_15m_10y_11d_bathy_no_sst_no_wind_mae_duacs_RonanUnet",
        "Eastward MSD Explained Variance (%)": 60.51,
        "Northward MSD Explained Variance (%)": 51.12,
        "Norm MSD Explained Variance (%)": 38.27,
        "Number of Points": 5555914.00
    },
    {
        "Mean": "unet_uv_aoml_15m_10y_11d_bathy_no_sst_ugos_mae_duacs_RonanUnet",
        "Eastward MSD Explained Variance (%)": 61.21,
        "Northward MSD Explained Variance (%)": 50.58,
        "Norm MSD Explained Variance (%)": 39.77,
        "Number of Points": 5555914.00
    },
    {
        "Mean": "unet_uv_aoml_15m_10y_11d_bathy_no_sst_lat_mae_duacs_RonanUnet",
        "Eastward MSD Explained Variance (%)": 62.51,
        "Northward MSD Explained Variance (%)": 52.90,
        "Norm MSD Explained Variance (%)": 42.47,
        "Number of Points": 5555914.00
    },
    {
        "Mean": "unet_uv_aoml_15m_10y_11d_bathy_no_sst_bathy_mae_duacs_RonanUnet",
        "Eastward MSD Explained Variance (%)": 62.63,
        "Northward MSD Explained Variance (%)": 53.01,
        "Norm MSD Explained Variance (%)": 42.79,
        "Number of Points": 5555914.00
    },
    {
        "Mean": "unet_uv_aoml_15m_10y_11d_bathy_no_sst_ssh_mae_duacs_RonanUnet",
        "Eastward MSD Explained Variance (%)": 62.79,
        "Northward MSD Explained Variance (%)": 53.13,
        "Norm MSD Explained Variance (%)": 42.92,
        "Number of Points": 5555914.00
    },
    {
        "Mean": "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet",
        "Eastward MSD Explained Variance (%)": 62.68,
        "Northward MSD Explained Variance (%)": 53.16,
        "Norm MSD Explained Variance (%)": 42.04,
        "Number of Points": 5555914.00
    },
    {
        "Mean": "unet_uv_aoml_15m_10y_11d_bathy_sst_mae_duacs_RonanUnet",
        "Eastward MSD Explained Variance (%)": 63.15,
        "Northward MSD Explained Variance (%)": 53.61,
        "Norm MSD Explained Variance (%)": 43.64,
        "Number of Points": 5555914.00
    }
]

# %%
import numpy
# Identifions la ligne de référence
reference_line = next(item for item in data if item["Mean"] == "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet")

# Ajoutons une clé "gain" à chaque modèle
for entry in data:
    if entry["Mean"] == reference_line["Mean"]:
        # Pour la référence, le gain est 0
        entry["gain"] = {
            "Eastward MSD Explained Variance (%)": 0,
            "Northward MSD Explained Variance (%)": 0,
            "Norm MSD Explained Variance (%)": 0
        }
        entry["mean_gain"] = 0
    else:
        # Calculons le gain pour les autres modèles
        entry["gain"] = {
            "Eastward MSD Explained Variance (%)":
                entry["Eastward MSD Explained Variance (%)"] - reference_line["Eastward MSD Explained Variance (%)"],
            "Northward MSD Explained Variance (%)":
                entry["Northward MSD Explained Variance (%)"] - reference_line["Northward MSD Explained Variance (%)"],
            "Norm MSD Explained Variance (%)":
                entry["Norm MSD Explained Variance (%)"] - reference_line["Norm MSD Explained Variance (%)"]
        }

        entry["mean_gain"] = numpy.mean(
                numpy.array([entry["Eastward MSD Explained Variance (%)"] - reference_line["Eastward MSD Explained Variance (%)"],
                entry["Northward MSD Explained Variance (%)"] - reference_line["Northward MSD Explained Variance (%)"],
                entry["Norm MSD Explained Variance (%)"] - reference_line["Norm MSD Explained Variance (%)"]]))
        
listkey_comp = ( 
           'Eastward MSD Explained Variance (%)', 'Northward MSD Explained Variance (%)','Norm MSD Explained Variance (%)')
# Affichons un exemple pour vérifier
for entry in data:
    print(f"Modèle: {entry['Mean']}")
    for var in listkey_comp:
        gain=entry['gain'][var]
        print(f"{gain:.1f}")
# Out:
# Modèle: unet_uv_aoml_15m_10y_11d_bathy_no_sst_no_wind_mae_duacs_RonanUnet
# -2.2
# -2.0
# -3.8
# Modèle: unet_uv_aoml_15m_10y_11d_bathy_no_sst_ugos_mae_duacs_RonanUnet
# -1.5
# -2.6
# -2.3
# Modèle: unet_uv_aoml_15m_10y_11d_bathy_no_sst_lat_mae_duacs_RonanUnet
# -0.2
# -0.3
# 0.4
# Modèle: unet_uv_aoml_15m_10y_11d_bathy_no_sst_bathy_mae_duacs_RonanUnet
# -0.0
# -0.1
# 0.8
# Modèle: unet_uv_aoml_15m_10y_11d_bathy_no_sst_ssh_mae_duacs_RonanUnet
# 0.1
# -0.0
# 0.9
# Modèle: unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs_RonanUnet
# 0.0
# 0.0
# 0.0
# Modèle: unet_uv_aoml_15m_10y_11d_bathy_sst_mae_duacs_RonanUnet
# 0.5
# 0.5
# 1.6

# %%
gain
# Out:
# {'Eastward MSD Explained Variance (%)': -2.1700000000000017,
#  'Northward MSD Explained Variance (%)': -2.039999999999999,
#  'Norm MSD Explained Variance (%)': -3.769999999999996}

# %%
data
# Out:
# [{'Mean': 'unet_uv_aoml_15m_10y_11d_bathy_no_sst_no_wind_mae_duacs_RonanUnet',
#   'Eastward MSD Explained Variance (%)': 60.51,
#   'Northward MSD Explained Variance (%)': 51.12,
#   'Norm MSD Explained Variance (%)': 38.27,
#   'Number of Points': 5555914.0,
#   'gain': {'Eastward MSD Explained Variance (%)': -2.1700000000000017,
#    'Northward MSD Explained Variance (%)': -2.039999999999999,
#    'Norm MSD Explained Variance (%)': -3.769999999999996}},
#  {'Mean': 'unet_uv_aoml_15m_10y_11d_bathy_no_sst_ugos_mae_duacs_RonanUnet',
#   'Eastward MSD Explained Variance (%)': 61.21,
#   'Northward MSD Explained Variance (%)': 50.58,
#   'Norm MSD Explained Variance (%)': 39.77,
#   'Number of Points': 5555914.0,
#   'gain': {'Eastward MSD Explained Variance (%)': -1.4699999999999989,
#    'Northward MSD Explained Variance (%)': -2.5799999999999983,
#    'Norm MSD Explained Variance (%)': -2.269999999999996}},
# ...

# %%
reference_model="unet_uv_aoml_15m_10y_11d_bathy_no_sst_ssh_mae_duacs_RonanUnet"
reference_entry = next(item for item in data if item["Mean"] == reference_model)
data_gain 
for model in list_xp_name:
    for var in listkey_comp:
        #var = listkey_comp[0]
        # Trouver le dictionnaire correspondant
        entry = next(item for item in data if item["Mean"] == model)
        # Accéder à la valeur souhaitée
        value_ref = reference_entry[var]
        value = entry[var]
        gain = value_ref - value

# %%
list_dict
# Out:
# [{'type_stat': 'Mean',
#   'path': '../../rec/unet_uv_aoml_15m_10y_11d_bathy_no_sst_no_wind_mae_duacs_RonanUnet/metric/Global/Eulerian_RMS_unet_uv_aoml_15m_10y_11d_bathy_no_sst_no_wind_mae_duacs_RonanUnet.pyo',
#   'name': 'unet_uv_aoml_15m_10y_11d_bathy_no_sst_no_wind_mae_duacs_RonanUnet'},
#  {'type_stat': 'Mean',
#   'path': '../../rec/unet_uv_aoml_15m_10y_11d_bathy_no_sst_ugos_mae_duacs_RonanUnet/metric/Global/Eulerian_RMS_unet_uv_aoml_15m_10y_11d_bathy_no_sst_ugos_mae_duacs_RonanUnet.pyo',
#   'name': 'unet_uv_aoml_15m_10y_11d_bathy_no_sst_ugos_mae_duacs_RonanUnet'},
#  {'type_stat': 'Mean',
#   'path': '../../rec/unet_uv_aoml_15m_10y_11d_bathy_no_sst_lat_mae_duacs_RonanUnet/metric/Global/Eulerian_RMS_unet_uv_aoml_15m_10y_11d_bathy_no_sst_lat_mae_duacs_RonanUnet.pyo',
#   'name': 'unet_uv_aoml_15m_10y_11d_bathy_no_sst_lat_mae_duacs_RonanUnet'},
#  {'type_stat': 'Mean',
# ...

# %%
base_outputdir = "../../"
list_xp_name=[#"unet_uv_drifters_aoml_15m_10y_11d_ugos_lat",
            "duacs_15m_8th",
            "globcurrent_15m_4th",
            "neurost_sst_ssh_15m_10th",
            #"unet_uv_drifters_aoml_15m_10y_11d_bathy_mld_mae",
            #"unet_uv_drifters_aoml_15m_10y_11d_bathy_no_wind_mae",
            #"unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost",
            "unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_duacs",
            #"unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_imt",
            #"unet_uv_aoml_15m_10y_11d_bathy_mae_neurost",
]
list_dict=[]
for xp_name in list_xp_name:
    outputdir = f'{base_outputdir}rec/{xp_name}/metric/Global'
    list_dict = list_dict+[{'type_stat':'Mean','path':outputdir+f'/Eulerian_RMS_{xp_name}.pyo','name':f'{xp_name}'}] 

display(DictTable_color(list_dict,keys=listkey_comp))
# Out:
# <table style='border-collapse: collapse; width: 100%; border: 1px solid #000000;'>
# <tr style='background-color: #f8f9fa; color: black;'>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Mean</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm RMSD</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Norm Correlation</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Eastward MSD Explained Variance (%)</b></td>
# <td style='border: 1px solid #000000; padding: 8px;'><b>Northward MSD Explained Variance (%)</b></td>
# ...

# %%
def compare_map(var,ref,to_eval,box=None):

        proj = cartopy.crs.PlateCarree()

        dic_p = {'RMSD': {'vmin': 0.1, 'vmax': 0.4, 'cmap': 'YlGnBu_r'},
                'STD': {'vmin': 0.1, 'vmax': 0.4, 'cmap': 'YlGnBu'},
                'Correlation': {'vmin': 0.6, 'vmax':1, 'cmap': 'YlGnBu'},
                'Explained Variance (%)': {'vmin': 50, 'vmax': 85, 'cmap': 'YlGnBu'},
                'MSD Explained Variance (%)': {'vmin': 50, 'vmax': 85, 'cmap': 'YlGnBu'},
                'Quadratic Error (%)': {'vmin': 30, 'vmax': 65, 'cmap': 'YlGnBu_r'}
                }
        dic_diff = {'RMSD': {'vmin': -0.02, 'vmax': 0.02, 'cmap': 'RdBu_r'},
                'STD': {'vmin': -0.1, 'vmax': -0., 'cmap': 'YlGnBu'},
                'Correlation': {'vmin': -0.10, 'vmax':0.10, 'cmap': 'RdBu'},
                'Explained Variance (%)': {'vmin': -20, 'vmax': 20, 'cmap':'RdBu'},
                'MSD Explained Variance (%)': {'vmin': -20, 'vmax': 20, 'cmap':'RdBu'},
                'Quadratic Error (%)': {'vmin': -10, 'vmax': 10, 'cmap': 'RdBu_r'}
                }
        ind = 0

        print(f'Diagnostic {var}')
        #print(listdir)
        dic_p = dic_diff
        #ref = listdir[2]
        print(f"ref : {os.path.splitext(os.path.basename(ref))[0]}")
        print(f"to eval : {os.path.splitext(os.path.basename(to_eval))[0]}")
        #print(f'{os.path.splitext(os.path.basename(ref))[0].split('_')[2:]} vs {os.path.splitext(os.path.basename(file))[0].split('_')[2:]}')

        title_ref = os.path.splitext(os.path.basename(ref))[0]
        title_ref = title_ref.split('_')
        title_ref = '_'.join(title_ref[2:])

        title_eval = os.path.splitext(os.path.basename(to_eval))[0]
        title_eval = title_eval.split('_')
        title_eval = '_'.join(title_eval[2:])

        #for file in to_eval:
        bn =  os.path.dirname(to_eval)
        title = os.path.splitext(os.path.basename(to_eval))[0]
        title_list = title.split('_')
        title = '_'.join(title_list[2:])
        fig = eulerian_drifters.plot_bin_diff(to_eval, ref, bn, var,
                                        box= box, 
                                        vmin=dic_p[var]['vmin'],
                                        vmax=dic_p[var]['vmax'],
                                        cmap=dic_p[var]['cmap'],
                                        proj=proj)
        fig.suptitle(f'{var} {title_ref} (ref) vs {title_eval}')

# %%
# Comparer 4-2 ; 0-3
base_output="../../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
#var = 'RMSD'
#var = "Correlation"
var = "MSD Explained Variance (%)"

for region in list_region:

     #ref = listdir[0]
     xp_name="neurost_sst_ssh_15m_10th" #"globcurrent_15m_4th" #"neurost_sst_ssh_15m_4th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name="unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet" #'unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic MSD Explained Variance (%)
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_10th
# to eval : Eulerian_BINNED_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet

# %%
box_cal = [-135, -115, 20, 50]
box_med = [-5.6, 16.8, 34.6, 44.6]
box_gs = [-80, -43, 25, 46.5 ]
box_agulhas = [11, 33, -44, -27]
box_NA = [-40, 0, 48, 68]

list_box = [box_cal,box_med,box_gs,box_agulhas,box_NA]

for box in list_box:

     compare_map(var,ref,to_eval,box=box)
# Out:
# Diagnostic MSD Explained Variance (%)
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_10th
# to eval : Eulerian_BINNED_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet
# Diagnostic MSD Explained Variance (%)
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_10th
# to eval : Eulerian_BINNED_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet
# Diagnostic MSD Explained Variance (%)
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_10th
# to eval : Eulerian_BINNED_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet
# Diagnostic MSD Explained Variance (%)
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_10th
# to eval : Eulerian_BINNED_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet
# Diagnostic MSD Explained Variance (%)
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_10th
# to eval : Eulerian_BINNED_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost_RonanUnet

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
#var = 'RMSD'
#var = "Correlation"
var = "MSD Explained Variance (%)"

for region in list_region:

     #ref = listdir[0]
     xp_name="globcurrent_15m_4th" #"globcurrent_15m_4th" #"neurost_sst_ssh_15m_4th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name="unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost" #'unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

box_cal = [-135, -115, 20, 50]

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
#var = 'RMSD'
var = "Correlation"
#var = "MSD Explained Variance (%)"

for region in list_region:

     #ref = listdir[0]
     xp_name="globcurrent_15m_4th" #"globcurrent_15m_4th" #"neurost_sst_ssh_15m_4th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name="unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost" #"unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost" #'unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=box_cal)
# Out:
# Diagnostic Correlation
# ref : Eulerian_BINNED_globcurrent_15m_4th
# to eval : Eulerian_BINNED_unet_uv_aoml_15m_10y_11d_bathy_no_sst_mae_neurost

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'RMSD'
var = "Correlation"
#var = "MSD Explained Variance (%)"

for region in list_region:

     #ref = listdir[0]
     xp_name="neurost_sst_ssh_15m_10th" #"globcurrent_15m_4th" #"neurost_sst_ssh_15m_4th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name="unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae" #'unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic Correlation
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_10th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'RMSD'
#var = "Correlation"
#var = "MSD Explained Variance (%)"


for region in list_region:

     #ref = listdir[0]
     xp_name="neurost_sst_ssh_15m_10th" #"globcurrent_15m_4th" #"neurost_sst_ssh_15m_4th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name="unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost" #'unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic RMSD
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_10th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'Correlation'
#var ="MSD Explained Variance (%)"

for region in list_region:

     #ref = listdir[0]
     xp_name="unet_uv_drifters_aoml_15m_10y_11d_bathy_no_wind_mae" #"neurost_sst_ssh_15m_4th"
     ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     xp_name="unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae" #'unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic Correlation
# ref : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_wind_mae
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'Explained Variance (%)'

for region in list_region:

     #ref = listdir[0]
     xp_name="neurost_sst_ssh_15m_4th" #"neurost_sst_ssh_15m_4th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name="unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost" #'unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic Explained Variance (%)
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_4th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_neurost

# %% [markdown]
# GLOBCURRENT

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'Correlation'

for region in list_region:

     #ref = listdir[0]
     xp_name="globcurrent_15m_4th" #"neurost_sst_ssh_15m_4th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name="unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_sst_log" #'unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic Correlation
# ref : Eulerian_BINNED_globcurrent_15m_4th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae_sst_log

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'Explained Variance (%)'

for region in list_region:

     #ref = listdir[0]
     xp_name="globcurrent_15m_4th" #"neurost_sst_ssh_15m_4th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name="unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae"#'unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic Explained Variance (%)
# ref : Eulerian_BINNED_globcurrent_15m_4th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'Correlation'

for region in list_region:

     #ref = listdir[0]
     xp_name="globcurrent_15m_4th" #"neurost_sst_ssh_15m_4th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name="unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae" #'unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic Correlation
# ref : Eulerian_BINNED_globcurrent_15m_4th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae

# %% [markdown]
# NEUROST

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'Correlation'

for region in list_region:

     #ref = listdir[0]
     xp_name="neurost_sst_ssh_15m_4th" #"neurost_sst_ssh_15m_8th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name='unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic Correlation
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_4th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'Correlation'

for region in list_region:

     #ref = listdir[0]
     xp_name="neurost_sst_ssh_15m_4th" #"neurost_sst_ssh_15m_8th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name='unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic Correlation
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_4th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['Global']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'Explained Variance (%)'

for region in list_region:

     #ref = listdir[0]
     xp_name="neurost_sst_ssh_15m_4th" #"neurost_sst_ssh_15m_8th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name='unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval,box=[-180, 180, -70, 70])
# Out:
# Diagnostic Explained Variance (%)
# ref : Eulerian_BINNED_neurost_sst_ssh_15m_4th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['California']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'Correlation'

for region in list_region:

     #ref = listdir[0]
     xp_name="globcurrent_15m_4th" #"neurost_sst_ssh_15m_4th" #"neurost_sst_ssh_15m_8th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name='unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval)
# Out:
# Diagnostic Correlation
# ref : Eulerian_BINNED_globcurrent_15m_4th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae

# %%
# Comparer 4-2 ; 0-3
base_output="../rec"
list_region=['California']

depth = '15'
listvar = ('RMSD',  'Correlation', 'Explained Variance (%)', 'Quadratic Error (%)')
#var = 'Quadratic Error (%)'
var = 'Explained Variance (%)'

for region in list_region:

     #ref = listdir[0]
     xp_name= "globcurrent_15m_4th" #"neurost_sst_ssh_15m_4th" #"neurost_sst_ssh_15m_8th"
     if region=='T1':
          region='Agulhas'
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          ref = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"


     xp_name='unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae'#"ssh_duacs_sst_w_to_u_v_11d_15m"
     if region=='T1':
          region='Agulhas'
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"
     else:
          to_eval = f"{base_output}/{xp_name}/metric/{region}/Eulerian_BINNED_{xp_name}.pyo"

     compare_map(var,ref,to_eval)
# Out:
# Diagnostic Quadratic Error (%)
# ref : Eulerian_BINNED_globcurrent_15m_4th
# to eval : Eulerian_BINNED_unet_uv_drifters_aoml_15m_10y_11d_bathy_no_sst_mae
